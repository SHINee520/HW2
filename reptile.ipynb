# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = "https://movies.yahoo.com.tw/movie_intheaters.html"
r = requests.get(url)
soup = BeautifulSoup(r.text)

# %%
def find_href():
    href=[]
    for d in soup.find_all('div', class_="release_movie_name"):
        href.append(d.find('a', class_='gabtn')['href'])

    lista = []
    so= ''
    for a in href:
        url=a
        r = requests.get(url)
        so = BeautifulSoup(r.text)

        name_ch=so.find('h1').text.strip()
        name_en=so.find('h3').text.strip()
        date=so.find('div',class_= 'movie_intro_info_r').find('span').text.split('上映日期：')[1]

        types=''
        for c in so.find_all('div', class_="level_name_box"):
            for d in c.find_all('div', class_="level_name"):
                types+=d.find('a',class_='gabtn').text.strip()

        article=so.find('div',class_='gray_infobox_inner').find('span').text.strip()
        ind=(name_ch,name_en,date,types,article)
        lista.append(ind)

    df = pd.DataFrame(lista, columns = ["中文名稱", "英文名稱",'上映日期','類型','簡介',])
    # df.to_csv('movies.csv')
    return(df)
    # print(lista)
    


find_href()
# Out:
#                 中文名稱                                  英文名稱        上映日期  \
# 0               叢林奇航                         Jungle Cruise  2021-07-30
# 1  LIP X LIP享受這世界的方法                 LIP X LIP FILM X LIVE  2021-07-30
# 2             小王子公主心                          Petite Fille  2021-07-30
# 3               淘寶少年                          Sun Children  2021-07-30
# 4                 詭老                                   Old  2021-07-30
# 5                罪之聲                      The Voice of Sin  2021-07-30
# 6              破碎的瞬間  My Blood & Bones in a flowing Galaxy  2021-07-30
# 7      理髮師的男人 經典數位修復             The Hairdresser's Husband  2021-07-30
# 8                 除暴                        Caught In Time  2021-07-30
# 9             太陽出來之後                    Under the Open Sky  2021-07-30
#
#           類型                                                 簡介
# 0     動作冒險奇幻  故事描述一位名叫霍頓博士（艾蜜莉布朗 飾演）發現了深藏在亞馬遜裡，有著一顆擁有治癒神力的奇幻...
# 1         動畫  ★日本百萬訂閱品牌VOCALOID樂團HoneyWorks 10週年特別企劃，偶像團體組合「...
# 2        紀錄片  ★ 4座最佳紀錄片獎得主   千萬觀眾感動淚推，動人鉅獻！\r\n★ 紀錄人類幼小心靈的掙扎...
# 3         劇情  ★入選 威尼斯影展競賽片最佳影片\r\n★榮獲 威尼斯影展最佳新演員獎\r\n★2021 奧...
# 4      懸疑/驚悚  獨具遠見的導演奈沙馬蘭將推出一部令人不寒而慄、疑雲重重的全新驚悚片，故事描述一個家庭前往熱帶...
# 5    劇情懸疑/驚悚  ★ 實力派演員小栗旬、「全能才子」星野源首度精彩共演\r\n★ 改編自作家塩田武士以日本昭和...
# 6  奇幻劇情懸疑/驚悚  ★2021金馬奇幻影展 口碑好評沸騰\r\n★2020 華沙影展\r\n★2020 塔林黑夜...
# 7         愛情  “答應我一件事，當你不再愛我的那天，不要假裝你還愛我”\r\n安東自幼喜歡音樂和舞蹈，經常隨...
# 8       動作犯罪  ★ 超級硬派警匪決戰，6年內犯下破萬件搶案的最強悍匪與刑警強力對決\r\n★ 金獎影帝吳彥祖...
# 9         劇情  ★ 一個出獄大叔的救贖之路！改編自直木賞獲獎小說《身分帳》\r\n★ 芝加哥國際影展 多倫多...
